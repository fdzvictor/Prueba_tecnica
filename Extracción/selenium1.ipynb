# %% [markdown]
# ### Fase 2: Extracción de Detalles de Películas con Selenium
# Utiliza Selenium para obtener información adicional de las películas listadas previamente.
#
# **Información requerida:**
# - Calificación de IMDB.
# - Dirección (director o directores).
# - Guionistas.
# - Argumento.
# - Duración (en minutos).
#
# **Nota:** Los datos obtenidos deberán almacenarse en una lista de tuplas.

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from time import sleep
# Selenium para establecer la configuración del driver
# -----------------------------------------------------------------------
from selenium import webdriver

from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile
# Para generar una barra de proceso en los bucles for
# -----------------------------------------------------------------------

from tqdm import tqdm

# Para trabajar con ficheros
# -----------------------------------------------------------------------
import os
import json
import re
import pickle
import zipfile
import shutil

#Para leer los dataframes
#-------------------------------------------------------------------------
import pandas as pd

# %%
with open('tuple_list.pkl', 'rb') as f:

    lista_tuplas = pickle.load(f) 
    print(lista_tuplas)
# Out:
# [('tt0059325', 'Jahrgang 45', 1990, 'Drama'), ('tt0090665', 'Asfour Stah', 1990, 'Drama'), ('tt0075259', 'Spy Story', 1990, 'Mystery'), ('tt0059900', 'Wenn du groß bist, lieber Adam', 1990, 'Drama'), ('tt0094997', 'Demonia', 1990, 'Horror'), ('tt0075259', 'Spy Story', 1990, 'Mystery'), ('tt0059325', 'Jahrgang 45', 1990, 'Drama'), ('tt0075259', 'Spy Story', 1990, 'Mystery'), ('tt0077432', 'Dip huet kei bing', 1991, 'Action'), ('tt0088267', 'Tian di xuan men', 1991, 'Comedy'), ('tt0077432', 'Dip huet kei bing', 1991, 'Action'), ('tt0088267', 'Tian di xuan men', 1991, 'Comedy'), ('tt0093309', 'Jiang shi zhi zun', 1991, 'Comedy'), ('tt0099397', 'Defenseless', 1991, 'Mystery'), ('tt0094841', 'La casa del sorriso', 1991, 'Drama'), ('tt0094900', 'Committed', 1991, 'Drama'), ('tt0095761', "La nuit de l'océan", 1992, 'Drama'), ('tt0096154', 'Spies Inc.', 1992, 'Adventure'), ('tt0095335', 'Gun gun hong chun', 1992, 'Adventure'), ('tt0099055', 'The Argon Quest', 1992, 'Family'), ('tt0099562', 'Fertilize the Blaspheming Bombshell', 1992, 'Family'), ('tt0101625', 'Once Upon a Crime...', 1992, 'Crime'), ('tt0099192', 'Bush Pilots', 1992, 'Adventure'), ('tt0097631', 'Judgement', 1992, 'Music'), ('tt0015724', 'Dama de noche', 1993, 'Romance'), ('tt0081145', 'Me and the Kid', 1993, 'Drama'), ('tt0095745', 'Ninja Vengeance', 1993, 'Action'), ('tt0084551', 'Pu ti you hun', 1993, 'Horror'), ('tt0084551', 'Pu ti you hun', 1993, 'Horror'), ('tt0015724', 'Dama de noche', 1993, 'Romance'), ('tt0015724', 'Dama de noche', 1993, 'Romance'), ('tt0015724', 'Dama de noche', 1993, 'Romance'), ('tt0097416', 'Kadhalan', 1994, 'Romance'), ('tt0099483', 'Ed and Jenny', 1994, 'Romance'), ('tt0086847', 'Access Code', 1994, 'Sci-Fi'), ('tt0106346', 'El baile de las ánimas', 1994, 'Fantasy'), ('tt0100881', 'Voci dal profondo', 1994, 'Mystery'), ('tt0086847', 'Access Code', 1994, 'Sci-Fi'), ('tt0097416', 'Kadhalan', 1994, 'Romance'), ('tt0086847', 'Access Code', 1994, 'Sci-Fi'), ('tt0100267', 'Nobat e Asheghi', 1995, 'Drama'), ('tt0102952', 'Prima Donnas', 1995, 'Drama'), ('tt0101616', 'Coolie No. 1', 1995, 'Comedy'), ('tt0102532', 'Night Visions', 1995, 'Comedy'), ('tt0108576', 'Witch Academy', 1995, 'Comedy'), ('tt0109028', 'Á köldum klaka', 1995, 'Drama'), ('tt0100267', 'Nobat e Asheghi', 1995, 'Drama'), ('tt0095102', 'Les ennemis de la mafia', 1995, 'Drama'), ('tt0099840', 'In the Shadow of the Sandcastle', 1996, 'Crime'), ('tt0110028', 'Highway of Heartache', 1996, 'Comedy'), ('tt0110463', 'Mo him wong', 1996, 'Fantasy'), ('tt0110463', 'Mo him wong', 1996, 'Fantasy'), ('tt0112908', 'Drzewa', 1996, 'Drama'), ('tt0111305', 'Sucesos distantes', 1996, 'Mystery'), ('tt0111678', 'The Wedding Tape', 1996, 'Romance'), ('tt0103655', 'Almost Blue', 1996, 'Drama'), ('tt0102267', 'Lifebreath', 1997, 'Thriller'), ('tt0108294', 'Taranthriller', 1997, 'Comedy'), ('tt0112629', 'Captured Alive', 1997, 'Comedy'), ('tt0112856', 'Les deux orphelines vampires', 1997, 'Fantasy'), ('tt0112856', 'Les deux orphelines vampires', 1997, 'Fantasy'), ('tt0116611', 'Illicit Dreams 2', 1997, 'Mystery'), ('tt0102267', 'Lifebreath', 1997, 'Thriller'), ('tt0102267', 'Lifebreath', 1997, 'Thriller'), ('tt0108098', 'Shackles', 1998, 'Thriller'), ('tt0095469', 'Ku jia tian xia', 1998, 'Thriller'), ('tt0112340', 'Amaneció de golpe', 1998, 'Action'), ('tt0116943', 'Lurid Tales: The Castle Queen', 1998, 'Fantasy'), ('tt0118956', 'Deep Rising', 1998, 'Horror'), ('tt0119196', 'The Gingerbread Man', 1998, 'Mystery'), ('tt0110404', 'Luces de la noche', 1998, 'Drama'), ('tt0112340', 'Amaneció de golpe', 1998, 'Action'), ('tt0111068', 'Sangharsh', 1999, 'Horror'), ('tt0110445', 'Making Waves', 1999, 'Comedy'), ('tt0111068', 'Sangharsh', 1999, 'Horror'), ('tt0110445', 'Making Waves', 1999, 'Comedy'), ('tt0111068', 'Sangharsh', 1999, 'Horror'), ('tt0120500', 'When Justice Fails', 1999, 'Mystery'), ('tt0112444', "My Teacher's Wife", 1999, 'Comedy'), ('tt0111068', 'Sangharsh', 1999, 'Horror'), ('tt0102362', 'Ist ...

# %%
df = pd.DataFrame(lista_tuplas, columns= ["Codigo", "Titulo", "Año", "Genero"])
df = df.drop_duplicates()

# %%
lista_codigos = []
for codigo in df["Codigo"]:
    lista_codigos.append(codigo)

# %% [markdown]
# SCRAPEEMOS

# %%
#Scrapeo INE datos demográficos por provincia

# lo primero que vamos a hacer es configurar nuestras preferencias del navegador para el driver
options = webdriver.FirefoxOptions()
driver = webdriver.Firefox(options=options)

# establacemos las preferencias que queremos
prefs = {
    "download.default_directory": "C:\\Users\\Victor\\Desktop\\Hackio\\Proyectos\\Prueba_tecnica\\Extracción",  # AQUÍ CADA UNO TENDREMOS QUE PONER LA RUTA QUE QUERAMOS PARA QUE SE GUARDEN LOS ARCHIVOS DESCARGADOS
    "download.prompt_for_download": False,   # desactiva el diálogo que Chrome normalmente muestra para pedir confirmación del usuario antes de descargar un archivo
    "directory_upgrade": True,    # hace que Chrome actualice el directorio de descarga predeterminado a la nueva ubicación especificada por download.default_directory si esta ha cambiado.
    "safebrowsing.enabled": True # protegemos al driver de sitios web peligrosos
}

)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 4
#       1 #Scrapeo INE datos demográficos por provincia
#       2
#       3 # lo primero que vamos a hacer es configurar nuestras preferencias del navegador para el driver
# ----> 4 FirefoxOptions  = FirefoxOptions();
#       5 driver = FirefoxDriver(options);
#       7 # establacemos las preferencias que queremos
#
# NameError: name 'FirefoxOptions' is not defined

# %%
try:
    url_IMDB = ("https://www.imdb.com/es-es/")
    driver= webdriver.Firefox(options = options)
    driver.get(url_IMDB)    
    print("entramos en la web")
    driver.maximize_window()
    sleep(2)

    WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, "/html/body/div[2]/nav/div[2]/div[2]/form/div[2]/div/input"))
        ).click()
    print("hemos clickado en la barra")

except Exception as e:
     
     print(f"{e}")
# Out:
# ['tt0059325',
#  'tt0090665',
#  'tt0075259',
#  'tt0059900',
#  'tt0094997',
#  'tt0077432',
#  'tt0088267',
#  'tt0093309',
#  'tt0099397',
#  'tt0094841',
#  'tt0094900',
#  'tt0095761',
#  'tt0096154',
#  'tt0095335',
#  'tt0099055',
#  'tt0099562',
#  'tt0101625',
#  'tt0099192',
#  'tt0097631',
#  'tt0015724',
#  'tt0081145',
#  'tt0095745',
#  'tt0084551',
#  'tt0097416',
#  'tt0099483',
#  'tt0086847',
#  'tt0106346',
#  'tt0100881',
#  'tt0100267',
#  'tt0102952',
#  'tt0101616',
#  'tt0102532',
#  'tt0108576',
#  'tt0109028',
#  'tt0095102',
#  'tt0099840',
#  'tt0110028',
#  'tt0110463',
#  'tt0112908',
#  'tt0111305',
#  'tt0111678',
#  'tt0103655',
#  'tt0102267',
#  'tt0108294',
#  'tt0112629',
#  'tt0112856',
#  'tt0116611',
#  'tt0108098',
#  'tt0095469',
#  'tt0112340',
#  'tt0116943',
#  'tt0118956',
#  'tt0119196',
#  'tt0110404',
#  'tt0111068',
#  'tt0110445',
#  'tt0120500',
#  'tt0112444',
#  'tt0102362',
#  'tt0119495',
#  'tt0113092',
#  'tt0128158',
#  'tt0120753',
#  'tt0079644',
#  'tt0035423',
#  'tt0114447',
#  'tt0118652',
#  'tt0114722',
#  'tt0096056',
#  'tt0120912',
#  'tt0121765',
#  'tt0120804',
#  'tt0120679',
#  'tt0118926',
#  'tt0119727',
#  'tt0117461',
#  'tt0167260',
#  'tt0156100',
#  'tt0199626',
#  'tt0160870',
#  'tt0092960',
#  'tt0108549',
#  'tt0131597',
#  'tt0167190',
#  'tt0122247',
#  'tt0168064',
#  'tt0118141',
#  'tt0088751',
#  'tt0121766',
#  'tt0153517',
#  'tt0121164',
#  'tt0160706',
#  'tt0110476',
#  'tt0136517',
#  'tt0206634',
#  'tt0279688',
#  'tt0144280',
#  'tt0270417',
#  'tt0196186',
#  'tt0119231',
#  'tt0259324',
#  'tt0243649',
#  'tt0317401',
#  'tt0211933',
#  'tt0075959',
#  'tt0198794',
#  'tt0117743',
#  'tt0115686',
#  'tt0036177',
#  'tt0319115',
#  'tt0406759',
#  'tt0119970',
#  'tt0143558',
#  'tt0153140',
#  'tt0205380',
#  'tt0293354',
#  'tt0289146',
#  'tt0121569',
#  'tt0146592',
#  'tt0331312',
#  'tt0411951',
#  'tt0398286',
#  'tt0436230',
#  'tt0326965',
#  'tt0393049',
#  'tt0176694',
#  'tt0376136',
#  'tt0372538',
#  'tt0210470',
#  'tt0323808',
#  'tt0311448',
#  'tt0337692',
#  'tt0249516',
#  'tt0431021',
#  'tt0293069',
#  'tt0255820',
#  'tt0469021',
#  'tt0359950',
#  'tt0496375',
#  'tt0463960',
#  'tt0409379',
#  'tt0338258',
#  'tt0016906',
#  'tt0329539',
#  'tt0464054',
#  'tt0365907',
#  'tt0297400',
#  'tt0191476',
#  'tt0369610',
#  'tt10210636',
#  'tt10162794',
#  'tt1014763',
#  'tt0790770',
#  'tt0420293',
#  'tt0315642',
#  'tt0475290',
#  'tt0803096',
#  'tt0775440',
#  'tt0443533',
#  'tt0087963',
#  'tt0451279',
#  'tt0100275',
#  'tt0112502',
#  'tt0137204',
#  'tt0491203',
#  'tt0069049',
#  'tt0111414',
#  'tt0276568',
#  'tt10074540',
#  'tt0862930',
#  'tt0859635',
#  'tt0365545',
#  'tt0360556',
#  'tt0011216',
#  'tt0448115',
#  'tt0011801',
#  'tt0837563',
#  'tt0385887',
#  'tt0810836',
#  'tt0437086',
#  'tt0062336',
#  'tt0446792',
#  'tt0849437',
#  'tt0805647',
#  'tt0093119',
#  'tt0228802',
#  'tt0326716',
#  'tt0293429',
#  'tt0993840',
#  'tt0346172',
#  'tt0965381',
#  'tt10090058',
#  'tt0887261',
#  'tt10028196',
#  'tt0451272',
#  'tt10298848',
#  'tt10151854',
#  'tt0439572',
#  'tt1001520',
#  'tt10757454',
#  'tt10366206',
#  'tt10579986',
#  'tt10408218',
#  'tt11078340',
#  'tt11152168',
#  'tt14978566',
#  'tt12794380']
